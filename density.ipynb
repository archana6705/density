# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
response=requests.get(url="https://realpython.com/")

# %%
print(response.text)
# Out:
# <!doctype html>
# <html lang="en">
#   <head>
#
#
#     <link href="https://files.realpython.com" rel="preconnect">
#
#     <title>Python Tutorials – Real Python</title>
#     <meta name="author" content="Real Python">
#     <meta name="description" content="Learn Python online: Python tutorials for developers of all skill levels, Python books and courses, Python news, code examples, articles, and more.">
#     <meta name="keywords" content="">
#
#
#
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no, viewport-fit=cover">
#
#
#       <link rel="stylesheet" href="/static/realpython.min.3107e3a57ed2.css">
#       <link rel="stylesheet" href="/static/gfonts/font.5ac42994de49.css">
#       <link rel="preload" href="/static/glightbox.min.9b438b29cef1.css" as="style" onload="this.onload=null;this.rel='stylesheet'"><noscript><link rel="stylesheet" href="/static/glightbox.min.9b438b29cef1.css"></noscript>
#
#
#
#
#
#
#
# ...

# %%
print(type(response.text))
# Out:
# <class 'str'>

# %%
html_doc=response.text

# %%
soup=BeautifulSoup(html_doc,"html.parser")

# %%
titles=soup.find_all("h2",class_="card-title")
titles
# Out:
# [<h2 class="card-title h2 my-0 py-0">Building a Python Command-Line To-Do App With Typer</h2>,
#  <h2 class="card-title h4 my-0 py-0">How to Join Strings in Python</h2>,
#  <h2 class="card-title h4 my-0 py-0">How to Split a String in Python</h2>,
#  <h2 class="card-title h4 my-0 py-0">NumPy Techniques and Practical Examples</h2>,
#  <h2 class="card-title h4 my-0 py-0">Python for Loops: The Pythonic Way</h2>,
#  <h2 class="card-title h4 my-0 py-0">Build a Quiz Application With Python</h2>,
#  <h2 class="card-title h4 my-0 py-0">Top Python Game Engines</h2>,
#  <h2 class="card-title h4 my-0 py-0">Develop Data Visualization Interfaces in Python With Dash</h2>,
#  <h2 class="card-title h4 my-0 py-0">Build a Dice-Rolling Application With Python</h2>,
#  <h2 class="card-title h4 my-0 py-0">Python &amp; APIs: A Winning Combo for Reading Public Data</h2>,
#  <h2 class="card-title h4 my-0 py-0">A Guide to Modern Python String Formatting Tools</h2>,
# ...

# %%
"""data=[]
for i in titles:
    #print(i.text)
    data.append(i.text)
data"""
data=[i.text for i in titles]
data
# Out:
# ['Building a Python Command-Line To-Do App With Typer',
#  'How to Join Strings in Python',
#  'How to Split a String in Python',
#  'NumPy Techniques and Practical Examples',
#  'Python for Loops: The Pythonic Way',
#  'Build a Quiz Application With Python',
#  'Top Python Game Engines',
#  'Develop Data Visualization Interfaces in Python With Dash',
#  'Build a Dice-Rolling Application With Python',
#  'Python & APIs: A Winning Combo for Reading Public Data',
#  'A Guide to Modern Python String Formatting Tools',
#  'Providing Multiple Constructors in Your Python Classes',
#  'Build a Tic-Tac-Toe Game With Python and Tkinter',
#  'Natural Language Processing With spaCy in Python',
#  "Split Your Dataset With scikit-learn's train_test_split()",
#  'Creating a Scalable Flask Web Application From Scratch',
#  'How to Split a Python List or Iterable Into Chunks',
#  'Python\'s "in" and "not in" Operators: Check for Membership',
#  'Python Folium: Create Web Maps From Your Data']

# %%
DIC ={"CARD TITLES":data}
DIC
# Out:
# {'CARD TITLES': ['Building a Python Command-Line To-Do App With Typer',
#   'How to Join Strings in Python',
#   'How to Split a String in Python',
#   'NumPy Techniques and Practical Examples',
#   'Python for Loops: The Pythonic Way',
#   'Build a Quiz Application With Python',
#   'Top Python Game Engines',
#   'Develop Data Visualization Interfaces in Python With Dash',
#   'Build a Dice-Rolling Application With Python',
#   'Python & APIs: A Winning Combo for Reading Public Data',
#   'A Guide to Modern Python String Formatting Tools',
#   'Providing Multiple Constructors in Your Python Classes',
#   'Build a Tic-Tac-Toe Game With Python and Tkinter',
#   'Natural Language Processing With spaCy in Python',
#   "Split Your Dataset With scikit-learn's train_test_split()",
#   'Creating a Scalable Flask Web Application From Scratch',
#   'How to Split a Python List or Iterable Into Chunks',
#   'Python\'s "in" and "not in" Operators: Check for Membership',
# ...

# %%
import pandas as x
df = x.DataFrame(DIC)
df
# Out:
#                                           CARD TITLES
# 0   Building a Python Command-Line To-Do App With ...
# 1                       How to Join Strings in Python
# 2                     How to Split a String in Python
# 3             NumPy Techniques and Practical Examples
# 4                  Python for Loops: The Pythonic Way
# 5                Build a Quiz Application With Python
# 6                             Top Python Game Engines
# 7   Develop Data Visualization Interfaces in Pytho...
# 8        Build a Dice-Rolling Application With Python
# 9   Python & APIs: A Winning Combo for Reading Pub...
# 10   A Guide to Modern Python String Formatting Tools
# 11  Providing Multiple Constructors in Your Python...
# 12   Build a Tic-Tac-Toe Game With Python and Tkinter
# 13   Natural Language Processing With spaCy in Python
# 14  Split Your Dataset With scikit-learn's train_t...
# 15  Creating a Scalable Flask Web Application From...
# ...

# %%
df.to_csv("CARD_TITLES.csv")

# %%
df.index=range(1,len(df)+1)
df
# Out:
#                                           CARD TITLES
# 1   Building a Python Command-Line To-Do App With ...
# 2                       How to Join Strings in Python
# 3                     How to Split a String in Python
# 4             NumPy Techniques and Practical Examples
# 5                  Python for Loops: The Pythonic Way
# 6                Build a Quiz Application With Python
# 7                             Top Python Game Engines
# 8   Develop Data Visualization Interfaces in Pytho...
# 9        Build a Dice-Rolling Application With Python
# 10  Python & APIs: A Winning Combo for Reading Pub...
# 11   A Guide to Modern Python String Formatting Tools
# 12  Providing Multiple Constructors in Your Python...
# 13   Build a Tic-Tac-Toe Game With Python and Tkinter
# 14   Natural Language Processing With spaCy in Python
# 15  Split Your Dataset With scikit-learn's train_t...
# 16  Creating a Scalable Flask Web Application From...
# ...

# %%
response=requests.get(url="https://visaguide.world/asia/")

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# 	<link rel="profile" href="https://gmpg.org/xfn/11">
# 	<meta name='robots' content='index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1' />
# 	<style>img:is([sizes="auto" i], [sizes^="auto," i]) { contain-intrinsic-size: 3000px 1500px }</style>
#
# 	<!-- This site is optimized with the Yoast SEO plugin v24.2 - https://yoast.com/wordpress/plugins/seo/ -->
# ...

# %%
print(type(response.text))
# Out:
# <class 'str'>

# %%
html_doc=response.text

# %%
soup=BeautifulSoup(html_doc,"html.parser")

# %%
table=soup.find_all("table")

# %%
headings=table[1].find_all("th")
headings
# Out:
# [<th>Country</th>,
#  <th>Capital</th>,
#  <th>Area km2</th>,
#  <th>Population (2021)</th>]

# %%
rows=table[1].find_all("td")
rows
# Out:
# [<td>Afghanistan</td>,
#  <td>Kabul</td>,
#  <td>652,864</td>,
#  <td>39,835,428</td>,
#  <td>Armenia</td>,
#  <td>Yerevan</td>,
#  <td>29,743</td>,
#  <td>2,968,127</td>,
#  <td>Azerbaijan</td>,
#  <td>Baku</td>,
#  <td>86,600</td>,
#  <td>10,223,342</td>,
#  <td>Bahrain</td>,
#  <td>Manama</td>,
#  <td>760</td>,
#  <td>1,748,296</td>,
#  <td>Bangladesh</td>,
#  <td>Dhaka</td>,
#  <td>147,570</td>,
#  <td>166,303,498</td>,
#  <td>Bhutan</td>,
#  <td>Thimphu</td>,
#  <td>38,394</td>,
#  <td>779,898</td>,
#  <td>Brunei</td>,
#  <td>Bandar Seri Begawan</td>,
#  <td>5,765</td>,
#  <td>441,532</td>,
#  <td>Cambodia</td>,
#  <td>Phnom Penh</td>,
#  <td>181,035</td>,
#  <td>16,946,438</td>,
#  <td>China (PRC)</td>,
#  <td>Beijing</td>,
#  <td>9,596,961</td>,
#  <td>1,444,216,107</td>,
#  <td>East Timor</td>,
#  <td>Dili</td>,
#  <td>14,874</td>,
#  <td>1,343,873</td>,
#  <td>Georgia</td>,
#  <td>Tbilisi</td>,
#  <td>69,700</td>,
#  <td>3,979,765</td>,
#  <td>Hong Kong</td>,
# ...
